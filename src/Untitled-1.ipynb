# %%
import pandas as pd

df = pd.read_csv("data/sample.csv")

print("Shape:", df.shape)
print(df.head())
print(df.describe())
# Out:
# Shape: (4, 3)
#      name  score  passed
# 0    Alaa     88    True
# 1   Islam     74    True
# 2  Khaled     59   False
# 3    Sara     93    True
#            score
# count   4.000000
# mean   78.500000
# std    15.286159
# min    59.000000
# 25%    70.250000
# 50%    81.000000
# 75%    89.250000
# max    93.000000
